# %% [markdown]
# <a href="https://colab.research.google.com/github/GayaniWeerasinghe/DL_LAB-01/blob/master/Task1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
array = (4,4)
result1 = np.random.exponential(1, array)

# %%
result1
# Out:
# array([[0.33782336, 1.91356891, 2.64762006, 1.54007291],
#        [0.10836689, 2.18536188, 1.00257612, 0.09340907],
#        [0.91166075, 0.82928303, 0.25793372, 0.46547789],
#        [1.00066424, 2.50583722, 0.16747541, 0.10826888]])

# %%
array = (1000,1)
result2 = np.random.exponential(1, array)
print(result2)
# Out:
# [[7.62204274e-01]
#  [2.06814436e+00]
#  [2.35084762e+00]
#  [1.13055317e+00]
#  [3.55868824e-01]
#  [1.63879286e+00]
#  [2.66601209e+00]
#  [3.95947754e-01]
#  [9.02212420e-01]
#  [3.75662448e-01]
#  [7.73512106e-01]
#  [1.39663914e+00]
#  [9.61153188e-01]
#  [2.33087234e+00]
#  [2.07114871e+00]
#  [5.12481841e-02]
#  [1.03379243e-01]
#  [9.51114580e-02]
#  [5.17291732e-01]
#  [8.72829227e-02]
#  [1.44430740e-01]
#  [2.39548942e+00]
#  [6.77003191e-01]
#  [1.06285731e+00]
#  [5.44348243e-01]
#  [2.04667607e-01]
#  [1.47255986e+00]
#  [5.21304922e-02]
#  [6.02730894e+00]
#  [5.08003148e-01]
#  [4.41433918e-01]
#  [2.29760829e+00]
#  [1.09310493e+00]
#  [5.09062839e-01]
#  [1.32718850e+00]
#  [1.80535811e-02]
#  [4.39563130e-01]
#  [1.24168515e-01]
#  [1.34421458e+00]
#  [1.01241570e-01]
#  [1.11244182e+00]
#  [1.72891752e-01]
#  [2.43308764e-01]
#  [1.06228215e+00]
#  [1.07841920e+00]
#  [1.16817196e+00]
#  [1.33088396e+00]
#  [1.15457082e+00]
#  [1.66046407e+00]
#  [1.99606947e+00]
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(np.random.rand(100000), density=True, bins=200, histtype="step", color="blue", label="rand")
plt.axis([-2.5, 2.5, 0, 1.1])
plt.legend(loc = "upper left")
plt.title("Random distributions")
plt.xlabel("Value")
plt.ylabel("Density")
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D

x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
X, Y = np.meshgrid(x, y)
G = np.sqrt(X*2 + Y*2)
Z = np.sin(G)

figure = plt.figure(1, figsize = (12, 4))
subplot3d = plt.subplot(111, projection='3d')
surface = subplot3d.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=plt.cm.coolwarm, linewidth=0.1)
plt.show()
# Out:
# <ipython-input-8-ef22d551cfaf>:6: RuntimeWarning: invalid value encountered in sqrt
#   G = np.sqrt(X*2 + Y*2)
